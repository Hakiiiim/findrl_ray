# %%
import pickle
import pandas 
with open('model/checkpoint_000026/policies/default_policy/policy_state.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
# {'weights': {'_logits._model.0.weight': array([[ 0.00981254, -0.00782438, -0.00515505, ..., -0.01305522,
#            0.00328638,  0.00076144],
#          [-0.00028219, -0.00044694,  0.01432422, ...,  0.00683998,
#            0.0092965 ,  0.00109991],
#          [ 0.0088375 , -0.01296663,  0.00581486, ...,  0.00281815,
#            0.00486588,  0.00319116],
#          ...,
#          [ 0.00396952, -0.00055852,  0.00339628, ...,  0.00369718,
#            0.00510363, -0.00045232],
#          [ 0.00021219,  0.00632694,  0.00085194, ..., -0.00754166,
#           -0.00508902, -0.0001701 ],
#          [ 0.00165675,  0.00099839, -0.01212724, ..., -0.00041136,
#            0.00115781,  0.00587938]], dtype=float32),
#   '_logits._model.0.bias': array([-0.0311366 ,  0.04744764, -0.01450188,  0.00134311,  0.09552891,
#           0.10655052, -0.05022715,  0.02719199, -0.04328272, -0.04046966,
#           0.00394848, -0.03882161,  0.01486003, -0.03935082, -0.07707611,
# ...
