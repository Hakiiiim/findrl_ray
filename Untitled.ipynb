# %%
import pickle
import pandas 
with open('./model/checkpoint_001000/policies/default_policy/policy_state.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
# {'weights': OrderedDict([('default_policy/fc_1/kernel',
#                array([[-0.067428  ,  0.16966504,  0.21959263, ..., -0.17511839,
#                        -0.10500124, -0.04466707],
#                       [-0.11180157,  0.2160653 ,  0.05076884, ...,  0.04220833,
#                        -0.17961426, -0.07319145],
#                       [-0.06932671,  0.2242531 ,  0.2105829 , ..., -0.05283973,
#                        -0.13603984, -0.10823046],
#                       ...,
#                       [-0.10152509,  0.19753881,  0.24028553, ...,  0.0131939 ,
#                        -0.05357348, -0.01579396],
#                       [ 0.01020284,  0.22265705,  0.16175547, ..., -0.05004527,
#                        -0.01869855, -0.11197914],
#                       [-0.03272825,  0.24150072,  0.17344539, ..., -0.02948472,
#                        -0.03022381, -0.10908381]], dtype=float32)),
#               ('default_policy/fc_1/bias',
# ...
